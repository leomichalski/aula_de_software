# %% [markdown]
# <img align="center" width="300" height="300" src="data:image/jpeg;base64,...">

# %% [markdown]
# # **EDRA, Aula de Software**

# %% [markdown]
# ## **Ementa:**

# %% [markdown]
# 1. **A área de software da EDRA.**
#     1. Quem é quem? Quem faz o que?
#     2. Qual a diferença entre Software e Controle? O que Software faz?
#     3. Quais são os principais problemas que Software encara?
#     4. Vídeo do Felipe Kataoka, primeiro líder de software.
# 2. **Introdução à Visão Computacional.**
#     1. Oportunidades de mercado
#     2. O que é Inteligência Artificial?
#     3. Qual é a diferença entre Inteligência Artificial, Aprendizado de Máquina e Aprendizagem Profunda?
#     4. Como funcionam detectores de bordas?
#     5. O que é uma rede neural convolucional???
# 3. **Perguntas**
# 4. **(se der tempo) Workshop.**
#     0. Pré-requisitos: nenhum. Um pouco de programação ajuda.
#     1. Introdução ao Google Colab
#     2. Primeiros passos com TensorFlow no Google Colaboratory
#     3. Construa sua primeira rede neural profunda

# %% [markdown]
# #
# #
# #
# #

# %% [markdown]
# ## **1. A área de software da EDRA**

# %% [markdown]
# ### A. Quem é quem? Quem faz o que?
# - Eduarda Tavares - Design Gráfico com Unreal e outras ferramentas
# - Edson Soares - Desenvolvimento Mobile com Flutter
# - Gabrielle Ribeiro - Engenharia de Machine Learning com Python e TensorFlow
# - Leonardo Miranda - Pesquisa em Machine Learning e Gestão

# %% [markdown]
# ### B. Qual a diferença entre Software e Controle? O que Software faz?
# -
# -

# %% [markdown]
# ### C. Quais são os principais problemas que Software encara?
# - Limitação do tempo de voo.
# - Altura do voo.
# - Resolução da câmera.
# - Posicionamento da câmera no drone.
# - Custo computacional dos modelos de Aprendizado de Máquina.
# - Vídeo: https://www.youtube.com/watch?v=TiOKvOrYNII

# %% [markdown]
# #
# #

# %% [markdown]
# ## **2. Introdução à Visão Computacional**

# %% [markdown]
# ### **A. Oportunidades de mercado**
# - Detecção de pessoas com febre nas ruas por meio de drones
# - Airbus
#     - TODO
# - Tesla
#     - TODO: foto da visão de um carro tesla
#     - TODO: vaga de emprego
# - Jogos e Animação 3D
#     - TODO
# - Área Jurídica
#     - TODO
# - TikTok
#     - Software Engineer, Computer Vision: https://careers.tiktok.com/position/detail/6799070325595703560
#     - Researcher/Engineer in Computer Vision: https://www.linkedin.com/jobs/view/researcher-engineer-in-computer-vision-at-tiktok-1453537898/
# - Moda
#     - Prever o sucesso da venda de uma roupa em determinada região com base nas publicações da população nas redes sociais.
# - Proteção de copyright (YouTube)
#
# - Medicina, Manutenção Preditiva, Assinatura em vídeo, Varejo, Contagem de Estoque, etc, etc, etc.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### **B. O que é Inteligência Artificial?**
#
# Inteligência Artificial é um campo da Ciência da Computação que busca construir sistemas para computadores capazes de executar tarefas cognitivas de forma independente, reagindo de forma flexível ao seu ambiente maximizando a probabilidade de realizar com sucesso determinada tarefa.
#
# Por ser um campo ainda em desenvolvimento é difícil trazer uma definição única, mas de forma bem simples, pode-se dizer que a Inteligência Artificial faz com que computadores tenham a habilidade de pensar.
#
# O uso de Inteligência Artificial pode ser observado em veículos autônomos, chatbots, nas suas recomendações da Netflix, reconhecimento facial, etc.
#
# <img align="center" width="400" height="400" src="images/AI.png">

# %% [markdown]
# ### **C. Qual é a diferença entre Inteligência Artificial, Aprendizado de Máquina e Aprendizagem Profunda?**
#
# Acabamos de ver que a Inteligência Artificial é um campo muito amplo, que abrange diversas tarefas diferentes. Se pode afirmar que, de um modo geral, a IA busca reproduzir comportamentos humanos.
#
# Mas o que é então o Aprendizado de Máquina? Vejamos algumas definições:
#
# "Aprendizado de Máquina é o ramo da Inteligência Artificial baseado na ideia que sistemas podem aprender a partir de **dados, identificar padrões e tomar decisões** com o mínimo de intervenção humana" - SAS
#
# "Aprendizado de Máquina [...] tem o objetivo de ensinar computadores como aprender e agir **sem serem explicitamente programados**." - DeepAI
#
# Desse modo, o Aprendizado de Máquina faz uso de dados para treinar algoritmos. Durante o treinamento, o algoritmo aprende com esses dados e depois é capaz de fazer classificações ou previsões a respeito de algo. Pode-se dizer que um algoritmo de Aprendizado de Máquina é uma função matemática.
# Geralmente, esses algoritmos são divididos em três tipos:
#
#  - **Aprendizado Supervisionado:** o conjunto de dados de treinamento é acompanhado de labels que indicam a classe ou previsão esperada para cada entrada.
#
#  - **Aprendizado Não Supervisionado:** o conjunto de dados não possui labels. Isso significa que não existe uma resposta certa dada ao algoritmo, entretando é esperado que sejam encontrados padrões nos dados apresentados.
#
#  - **Aprendizado Por Reforço:** o computador aprende por meio de um sistema de recompensas.
#
# Mas o que significa não serem explicitamente programados?
#
# <img align="center" width="300" height="300" src="https://media.giphy.com/media/xUA7bhv4o0biM0WyOI/giphy.gif">
#
#
#
# Na programação comum escrevemos códigos que dizem as regras que o computador deve seguir. Já no aprendizado de máquina essas regras não são ditas ao algoritmo, na realidade ele descobre quais são essas regras durante o treinamento.
#
#
# <img align="center" width="500" height="500" src="images/ML.png">
#
# Legal, não?
#
# <img align="center" width="300" height="300" src="https://media.giphy.com/media/xT0xeJpnrWC4XWblEk/giphy.gif">
#
# Agora, só falta entender o que é Aprendizagem Profunda.
#
#
#
#
#
# Então podemos representar Inteligência Artificial, Aprendizado de Máquina e Aprendizagem Profunda com a seguinte imagem:
#
# <img align="center" width="500" height="500" src="images/Diferenca%20IA%20ML%20DL.png">
#
# Dentro da EDRA é muito comum o drone precisar resolver problemas que fazem parte do campo de visão computacional como a detecção de objetos. Para lidar com isso são utilizadas técnicas de Aprendizagem Profunda como Redes Neurais Convolucionais, que veremos mais adiante.

# %% [markdown]
# ### **D. O que é uma imagem?**
#
# Antes de entender mais detalhes sobre visão computacional é necessário saber como o computador enxerga uma imagem. Mas não se preocupe, pois é simples!
#
# Uma imagem para um computador nada mais é do que uma matriz de pixels, que possui um sistema de cores. Cada pixel é representado por um valor numérico.
#
# Exemplos:
#
# *Imagine que cada "quadradinho" das imagens a seguir são um pixel.*
#
# - Imagem com a resolução de 40x40x3 (RGB):
#
# <img align="center" width="300" height="300" src="images/bulbasaur.png">
#
# - Imagem com a resolução de 29x44x1 (grayscale):
#
# <img align="center" width="300" height="300" src="images/darth%20vader.png">
#
# Repare que a resolução das imagens é representada por 3 valores no formato A x L x C, onde A = altura (em pixels), L = largura (em pixels), D = Dimensão (escala de cor).
#
# Então uma imagem em RGB, por exemplo, possui uma dimensão de valor 3, pois sua escala de cor é referente a 3 cores: vermelho (Red), verde (Green), azul (Blue).
#
# O computador enxerga uma imagem RGB da seguinte maneira:
#
# <img align="center" width="400" height="400" src="images/matriz%20imagem.png">

# %% [markdown]
# ### **E. O que é uma convolução??**
#
# Matematicamente falando, uma convolução é uma operação linear que a partir de duas funções, gera uma terceira.
#
# Dentro do contexto de visão computacional a convolução consiste na extração das características relevantes de uma imagem, preservando as relações entre os pixels. A extração das características se dá por meio da multiplicação de pequenos blocos da matriz da imagem com um kernel (também chamado de feature detector ou filtro).
#
# <img align="center" width="400" height="400" src="images/multiplicacao%20da%20imagem%20pelo%20kernel.png">
#
# <img align="center" width="400" height="400" src="images/extracao%20feature%20map.gif">
#
# Mas afinal, o que é um kernel?
#
# <img align="center" width="300" height="300" src="https://media.giphy.com/media/xT0xeuOy2Fcl9vDGiA/giphy.gif">

# %% [markdown]
# ### **F. O que são filtros e kernels???**
#
# Um kernel nada mais é do que uma matriz utilizada na operação de multiplicação de matrizes durante o processamento de imagens. Diferentes kernels geram diferentes transformações na imagem.
#
# Exemplos de kernels:
#
# <img align="center" width="400" height="400" src="images/exemplos%20de%20kernels.png">

# %% [markdown]
# ### **G. O que é uma rede neural convolucional???**
#
# Redes Neurais Convolucionais (CNNs) são um tipo de rede neural frequentemente utilizadas no reconhecimento e/ou classificação de imagens.
#
# As CNNs são construídas por meio de 4 tipos de camadas: a camada de Convolução, a camada de Pooling, a camada de Flattening e a camada Densa.
#
# Agora, vamos entender como cada camada de uma rede convolucional funciona.
#
# #### **1. Camada de Convolução (Convolution Layer)**
#
# Essa camada aplica a operação de convolução, gerando o que chamamos de *feature map*, que é a imagem inicial com a dimensão reduzida, o que facilita seu processamento.
#
# Vale ressaltar que informações da imagem podem ser perdidas durante essa etapa, entretanto o objetivo é detectar as partes principais da imagem. Desse modo, o feature map preserva as principais características.
#
# Logo depois, o feature map é passado pela função ReLU. E agora você pode estar se perguntando "Função ReLU? O que é isso?"
#
# <img align="center" width="300" height="300" src="https://media.giphy.com/media/gKsJUddjnpPG0/giphy.gif">
#
# Se lembra da função de ativação que usamos na saída de cada neurônio da nossa rede neural? A função ReLU é um tipo de função de ativação que podemos utilizar. Sua expressão matemática é a seguinte: **f(x) = max(0,x)**.
#
# <img align="center" width="200" height="200" src="images/ReLU.png">
#
# A função ReLU transforma em 0 (zero) os valores negativos e mantém os valores positivos. Isso facilita a identificação de padrões na imagem pelo algoritmo.
#
# É possível utilizar outras funções de ativação, como tanh e sigmoid, entretanto a função ReLU é a mais utilizada nesse contexto.
#
# #### **2. Camada de Pooling (Pooling Layer)**
#
# A camada de pooling recebe o feature map e reduz sua dimensão, mas mantém as informações importantes da imagem. Essa camada reduz a quantidade de parâmetros quando temos uma imagem muito grande.
#
# Existem três tipos de pooling:
#
# - max pooling
# - average pooling
# - sum pooling
#
# No contexto das CNNs geralmente é utilizado o max pooling, pois o foco está nas características mais importantes.
#
# A aplicação do max pooling reduz os ruídos e o overfitting.
#
# <img align="center" width="400" height="400" src="images/Maxpooling.png">
#
# #### **3. Camada de Flattening (Flattening Layer)**
#
# A camada de Flattening recebe a imagem, que já passou pelo tratamento nas camadas de convolução e pooling, e transforma o formato de matriz em vetor. Desse modo, o valor de cada pixel pode ser utilizado como entrada para a próxima camada.
#
# <img align="center" width="400" height="400" src="images/flattening.png">
#
# #### **4. Camada Densa (Fully Conect Layer)**
#
# Essa é a última camada na rede neural convolucional. Ela recebe os valores da camada de flattening e funciona da forma que vimos anteriormente na explicação sobre Aprendizado Profundo, sendo essa camada responsável pelo reconhecimento ou classificação das imagens.
#
# <img align="center" width="400" height="400" src="images/fully%20conected%20layer.png">

# %% [markdown]
# ### **H. Funcionamento de uma Rede Neural Convolucional**
#
# Então, as redes neurais convolucionais são a junção de uma ou mais camadas de convolução + pooling com uma camada de flattening + uma rede densa no final.
#
# <img align="center" width="600" height="600" src="
# images/CNN.png">
#
# Viu como é simples?
#
# <img align="center" width="300" height="300" src="https://media.giphy.com/media/l0EwZ92cG9x9VPC7u/giphy.gif">

# %% [markdown]
# ### Agora você já sabe as diferenças entre Inteligência Artificial, Machine Learning e Deep Learning. E também como uma Rede Neural Convolucional funciona!!! Yay!!!
#
# <img align="center" width="300" height="300" src="https://media.giphy.com/media/yoJC2GnSClbPOkV0eA/giphy.gif">

# %% [markdown]
# #

# %% [markdown]
# ## **3. Perguntas**
#
# <img align="center" width="300" height="300" src="https://media.giphy.com/media/acJ6UbGLUB2De/giphy.gif">

# %% [markdown]
# ### A.

# %% [markdown]
# ### B.

# %% [markdown]
# ### C.

# %% [markdown]
# ### D.

# %% [markdown]
# # **"Talk is cheap, show me the code"** - Linus Torvalds
#
# Já que falar é fácil, vamos agora ao nosso Workshop !!!
#
# <img align="center" width="300" height="300" src="https://media.giphy.com/media/rVbAzUUSUC6dO/giphy.gif">

# %% [markdown]
# #

# %% [markdown]
# ## **4. Workshop**

# %% [markdown]
# ### 0. Pré-requisitos: nenhum. Um pouco de programação ajuda.

# %% [markdown]
# ### A. Introdução ao Google Colab. Baseado em https://www.youtube.com/watch?v=inN8seMm7UI

# %% [markdown]
# ### B. Primeiros passos com TensorFlow no Google Colaboratory. Baseado em https://www.youtube.com/watch?v=PitcORQSjNM

# %% [markdown]
# ### C. Construa sua primeira rede neural profunda. Baseado em https://www.youtube.com/watch?v=_VTtrSDHPwU

# %% [markdown]
# #

# %% [markdown]
# ## **Referências Bibliográficas**
#
# **A Five-Minute Guide To Artificial Inteligence**. Disponível em: https://medium.com/appanion/a-five-minute-guide-to-artificial-intelligence-c4262be85fd3
#
# **What is Artificial Intelligence? - In 5 minutes**. Disponível em: https://www.youtube.com/watch?v=2ePf9rue1Ao
#
# **Understanding of Convolutional Neural Network (CNN) - Deep Learning**. Disponível em: https://medium.com/@RaghavPrabhu/understanding-of-convolutional-neural-network-cnn-deep-learning-99760835f148
#
# **Uma introdução as redes neurais convolucionais utilizando o Keras**. Disponível em: https://medium.com/data-hackers/uma-introdu%C3%A7%C3%A3o-as-redes-neurais-convolucionais-utilizando-o-keras-41ee8dcc033e
#
# **A Beginner's Guide to Machine Learning.** Disponível em: https://medium.com/@randylaosat/a-beginners-guide-to-machine-learning-dfadc19f6caf
